# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import os

# %%
API_KEY = "STACK_APPS_API"

# %%
os.makedirs('./stackoverflow_dataset', exist_ok=True)

file_path = './stackoverflow_dataset/finetune_data_summarized.jsonl'
with open(file_path, 'w') as f:
    pass

# %%
def html_to_markdown_with_code(html):
    soup = BeautifulSoup(html, 'html.parser')

    for pre in soup.find_all('pre'):
        code = pre.code
        if code:
            lang = "js" if "javascript" in code.get('class', []) else ""
            block = code.get_text()
            markdown_block = f"\n```{lang}\n{block.strip()}\n```\n"
            pre.replace_with(markdown_block)

    for code in soup.find_all('code'):
        if code.parent.name != 'pre':
            inline = code.get_text()
            code.replace_with(f"`{inline.strip()}`")

    text = soup.get_text(separator="\n").strip()
    text = re.sub(r'\n{3,}', '\n\n', text)
    text = '\n'.join(line.rstrip() for line in text.splitlines())

    return text

# %%
SITE = "stackoverflow"
# Issues and their respective accepted answers are taken with this.
TAG = ["reactjs", "next.js", "vue.js", "frontend", "css", "html"]
API_BASE = "https://api.stackexchange.com/2.3"
PAGE_SIZE = 15

# %%
def get_questions_with_accepted_answer(tag, page=1):
    url = f"{API_BASE}/questions"
    params = {
        "order": "desc",
        "sort": "votes",
        "site": SITE,
        "tagged": tag,
        "filter": "withbody",
        "pagesize": PAGE_SIZE,
        "page": page,
        "key": API_KEY
    }
    resp = requests.get(url, params=params)
    data = resp.json()
    return [
        q for q in data.get('items', [])
        if q.get('accepted_answer_id')
    ], data.get("has_more", False)

def get_top_answer_body(question_id):
    url = f"{API_BASE}/questions/{question_id}/answers"
    params = {
        "order": "desc",
        "sort": "votes",
        "site": SITE,
        "filter": "withbody",
        "key": API_KEY
    }
    resp = requests.get(url, params=params)
    data = resp.json()
    if data.get('items'):
        soup = html_to_markdown_with_code(data['items'][0]['body'])
        return soup
    return None

# %%
def main():
    results = []
    for tag in TAG:
        page = 1
        while page <= 50:
            print("TAG:", tag, "Page:", page)
            questions, has_more = get_questions_with_accepted_answer(tag, page)
            for q in questions:
                title = html_to_markdown_with_code(q["title"])
                body = html_to_markdown_with_code(q["body"])
                question = title + "\n" + body
                question_id = q["question_id"]
                top_answer = get_top_answer_body(question_id)
                result = {
                    'messages': [
                        {"role": "user", "content": question},
                        {"role": "assistant", "content": top_answer}
                    ]
                }
                results.append(result)
                with open("./stackoverflow_dataset/finetune_data_summarized.jsonl", "a", encoding="utf-8") as f:
                    f.write(json.dumps(result, ensure_ascii=False) + "\n")
            page += 1

    print(f"Collected {len(results)} samples from Stack Overflow.")
    print("Data saved to stackoverflow_dataset/frontend_bugfix_dataset.jsonl")

# %%
main()
# Out:
# TAG: reactjs Page: 1
# TAG: reactjs Page: 2
# TAG: reactjs Page: 3
# TAG: reactjs Page: 4
# TAG: reactjs Page: 5
# TAG: reactjs Page: 6
# TAG: reactjs Page: 7
# TAG: reactjs Page: 8
# TAG: reactjs Page: 9
# TAG: reactjs Page: 10
# TAG: reactjs Page: 11
# TAG: reactjs Page: 12
# TAG: reactjs Page: 13
# TAG: reactjs Page: 14
# TAG: reactjs Page: 15
# TAG: reactjs Page: 16
# TAG: reactjs Page: 17
# TAG: reactjs Page: 18
# TAG: reactjs Page: 19
# TAG: reactjs Page: 20
# TAG: reactjs Page: 21
# TAG: reactjs Page: 22
# TAG: reactjs Page: 23
# TAG: reactjs Page: 24
# TAG: reactjs Page: 25
# TAG: reactjs Page: 26
# TAG: reactjs Page: 27
# TAG: reactjs Page: 28
# TAG: reactjs Page: 29
# TAG: reactjs Page: 30
# TAG: reactjs Page: 31
# TAG: reactjs Page: 32
# TAG: reactjs Page: 33
# TAG: reactjs Page: 34
# TAG: reactjs Page: 35
# TAG: reactjs Page: 36
# TAG: reactjs Page: 37
# TAG: reactjs Page: 38
# TAG: reactjs Page: 39
# TAG: reactjs Page: 40
# TAG: reactjs Page: 41
# TAG: reactjs Page: 42
# TAG: reactjs Page: 43
# TAG: reactjs Page: 44
# TAG: reactjs Page: 45
# TAG: reactjs Page: 46
# TAG: reactjs Page: 47
# TAG: reactjs Page: 48
# TAG: reactjs Page: 49
# TAG: reactjs Page: 50
# TAG: next.js Page: 1
# TAG: next.js Page: 2
# TAG: next.js Page: 3
# TAG: next.js Page: 4
# TAG: next.js Page: 5
# TAG: next.js Page: 6
# TAG: next.js Page: 7
# TAG: next.js Page: 8
# TAG: next.js Page: 9
# TAG: next.js Page: 10
# TAG: next.js Page: 11
# TAG: next.js Page: 12
# TAG: next.js Page: 13
# TAG: next.js Page: 14
# TAG: next.js Page: 15
# TAG: next.js Page: 16
# TAG: next.js Page: 17
# TAG: next.js Page: 18
# TAG: next.js Page: 19
# TAG: next.js Page: 20
# TAG: next.js Page: 21
# TAG: next.js Page: 22
# TAG: next.js Page: 23
# TAG: next.js Page: 24
# TAG: next.js Page: 25
# TAG: next.js Page: 26
# TAG: next.js Page: 27
# TAG: next.js Page: 28
# TAG: next.js Page: 29
# TAG: next.js Page: 30
# TAG: next.js Page: 31
# TAG: next.js Page: 32
# TAG: next.js Page: 33
# TAG: next.js Page: 34
# TAG: next.js Page: 35
# TAG: next.js Page: 36
# TAG: next.js Page: 37
# TAG: next.js Page: 38
# TAG: next.js Page: 39
# TAG: next.js Page: 40
# TAG: next.js Page: 41
# TAG: next.js Page: 42
# TAG: next.js Page: 43
# TAG: next.js Page: 44
# TAG: next.js Page: 45
# TAG: next.js Page: 46
# TAG: next.js Page: 47
# TAG: next.js Page: 48
# TAG: next.js Page: 49
# TAG: next.js Page: 50
# TAG: vue.js Page: 1
# TAG: vue.js Page: 2
# TAG: vue.js Page: 3
# TAG: vue.js Page: 4
# TAG: vue.js Page: 5
# TAG: vue.js Page: 6
# TAG: vue.js Page: 7
# TAG: vue.js Page: 8
# TAG: vue.js Page: 9
# TAG: vue.js Page: 10
# TAG: vue.js Page: 11
# TAG: vue.js Page: 12
# TAG: vue.js Page: 13
# TAG: vue.js Page: 14
# TAG: vue.js Page: 15
# TAG: vue.js Page: 16
# TAG: vue.js Page: 17
# TAG: vue.js Page: 18
# TAG: vue.js Page: 19
# TAG: vue.js Page: 20
# TAG: vue.js Page: 21
# TAG: vue.js Page: 22
# TAG: vue.js Page: 23
# TAG: vue.js Page: 24
# TAG: vue.js Page: 25
# TAG: vue.js Page: 26
# TAG: vue.js Page: 27
# TAG: vue.js Page: 28
# TAG: vue.js Page: 29
# TAG: vue.js Page: 30
# TAG: vue.js Page: 31
# TAG: vue.js Page: 32
# TAG: vue.js Page: 33
# TAG: vue.js Page: 34
# TAG: vue.js Page: 35
# TAG: vue.js Page: 36
# TAG: vue.js Page: 37
# TAG: vue.js Page: 38
# TAG: vue.js Page: 39
# TAG: vue.js Page: 40
# TAG: vue.js Page: 41
# TAG: vue.js Page: 42
# TAG: vue.js Page: 43
# TAG: vue.js Page: 44
# TAG: vue.js Page: 45
# TAG: vue.js Page: 46
# TAG: vue.js Page: 47
# TAG: vue.js Page: 48
# TAG: vue.js Page: 49
# TAG: vue.js Page: 50
# TAG: frontend Page: 1
# TAG: frontend Page: 2
# TAG: frontend Page: 3
# TAG: frontend Page: 4
# TAG: frontend Page: 5
# TAG: frontend Page: 6
# TAG: frontend Page: 7
# TAG: frontend Page: 8
# TAG: frontend Page: 9
# TAG: frontend Page: 10
# TAG: frontend Page: 11
# TAG: frontend Page: 12
# TAG: frontend Page: 13
# TAG: frontend Page: 14
# TAG: frontend Page: 15
# TAG: frontend Page: 16
# TAG: frontend Page: 17
# TAG: frontend Page: 18
# TAG: frontend Page: 19
# TAG: frontend Page: 20
# TAG: frontend Page: 21
# TAG: frontend Page: 22
# TAG: frontend Page: 23
# TAG: frontend Page: 24
# TAG: frontend Page: 25
# TAG: frontend Page: 26
# TAG: frontend Page: 27
# TAG: frontend Page: 28
# TAG: frontend Page: 29
# TAG: frontend Page: 30
# TAG: frontend Page: 31
# TAG: frontend Page: 32
# TAG: frontend Page: 33
# TAG: frontend Page: 34
# TAG: frontend Page: 35
# TAG: frontend Page: 36
# TAG: frontend Page: 37
# TAG: frontend Page: 38
# TAG: frontend Page: 39
# TAG: frontend Page: 40
# TAG: frontend Page: 41
# TAG: frontend Page: 42
# TAG: frontend Page: 43
# TAG: frontend Page: 44
# TAG: frontend Page: 45
# TAG: frontend Page: 46
# TAG: frontend Page: 47
# TAG: frontend Page: 48
# TAG: frontend Page: 49
# TAG: frontend Page: 50
# TAG: css Page: 1
# TAG: css Page: 2
# TAG: css Page: 3
# TAG: css Page: 4
# TAG: css Page: 5
# TAG: css Page: 6
# TAG: css Page: 7
# TAG: css Page: 8
# TAG: css Page: 9
# TAG: css Page: 10
# TAG: css Page: 11
# TAG: css Page: 12
# TAG: css Page: 13
# TAG: css Page: 14
# TAG: css Page: 15
# TAG: css Page: 16
# TAG: css Page: 17
# TAG: css Page: 18
# TAG: css Page: 19
# TAG: css Page: 20
# TAG: css Page: 21
# TAG: css Page: 22
# TAG: css Page: 23
# TAG: css Page: 24
# TAG: css Page: 25
# TAG: css Page: 26
# TAG: css Page: 27
# TAG: css Page: 28
# TAG: css Page: 29
# TAG: css Page: 30
# TAG: css Page: 31
# TAG: css Page: 32
# TAG: css Page: 33
# TAG: css Page: 34
# TAG: css Page: 35
# TAG: css Page: 36
# TAG: css Page: 37
# TAG: css Page: 38
# TAG: css Page: 39
# TAG: css Page: 40
# TAG: css Page: 41
# TAG: css Page: 42
# TAG: css Page: 43
# TAG: css Page: 44
# TAG: css Page: 45
# TAG: css Page: 46
# TAG: css Page: 47
# TAG: css Page: 48
# TAG: css Page: 49
# TAG: css Page: 50
# TAG: html Page: 1
# TAG: html Page: 2
# TAG: html Page: 3
# TAG: html Page: 4
# TAG: html Page: 5
# TAG: html Page: 6
# TAG: html Page: 7
# TAG: html Page: 8
# TAG: html Page: 9
# TAG: html Page: 10
# TAG: html Page: 11
# TAG: html Page: 12
# TAG: html Page: 13
# TAG: html Page: 14
# TAG: html Page: 15
# TAG: html Page: 16
# TAG: html Page: 17
# TAG: html Page: 18
# TAG: html Page: 19
# TAG: html Page: 20
# TAG: html Page: 21
# TAG: html Page: 22
# TAG: html Page: 23
# TAG: html Page: 24
# TAG: html Page: 25
# TAG: html Page: 26
# TAG: html Page: 27
# TAG: html Page: 28
# TAG: html Page: 29
# TAG: html Page: 30
# TAG: html Page: 31
# TAG: html Page: 32
# TAG: html Page: 33
# TAG: html Page: 34
# TAG: html Page: 35
# TAG: html Page: 36
# TAG: html Page: 37
# TAG: html Page: 38
# TAG: html Page: 39
# TAG: html Page: 40
# TAG: html Page: 41
# TAG: html Page: 42
# TAG: html Page: 43
# TAG: html Page: 44
# TAG: html Page: 45
# TAG: html Page: 46
# TAG: html Page: 47
# TAG: html Page: 48
# TAG: html Page: 49
# TAG: html Page: 50
# Collected 3495 samples from Stack Overflow.
# Data saved to stackoverflow_dataset/frontend_bugfix_dataset.jsonl

# %%
input_file_path = './stackoverflow_dataset/finetune_data_summarized.jsonl'
output_file_path = './stackoverflow_dataset/finetune_data_summarized_dedup.jsonl'

# Ensure the output directory exists
os.makedirs(os.path.dirname(output_file_path), exist_ok=True)

with open(input_file_path, 'r', encoding='utf-8') as f:
    data = [json.loads(line) for line in f]

# Remove duplicates
seen = set()
deduped_data = []
for entry in data:
    entry_str = json.dumps(entry, sort_keys=True)
    if entry_str not in seen:
        seen.add(entry_str)
        deduped_data.append(entry)

with open(output_file_path, 'w', encoding='utf-8') as f:
    for entry in deduped_data:
        f.write(json.dumps(entry, ensure_ascii=False) + '\n')
